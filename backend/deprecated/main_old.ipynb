# %%
from dotenv import load_dotenv
load_dotenv()

from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
# Setup Model for response validation
import regex as re
import pandas as pd
from pydantic import BaseModel, Field
from typing import Optional, List, Dict, Literal

class FinalResponse(BaseModel):
    original_user_query: str = Field(description="The user's original natural language query.")
    constructed_pandas_query: str = Field(description="The panda's query constructed to answer user's query.")
    output: str = Field(description="The result of the executed query.")
    charts: Optional[List[Dict]] = Field(default=None, description="List of charts generated, if any.")

class SupervisorResponse(BaseModel):
    next_action: Literal["FINISH", "EXECUTE_QUERY", "Schema_Query_Agent"]
    final_response: Optional[FinalResponse] = None

class SchemaQueryResponse(BaseModel):
    final_query: str = Field(description="The constructed single-line Pandas query.")

# %%
# Helper functions for Supervisor Agent
def extract_query_from_state(state):
    for message in reversed(state['messages']):
        if message.name == "Schema_Query_Agent":
            pattern = r"The constructed Pandas query is: (.*)"
            match = re.search(pattern, message.content)
            return match.group(1)
        else:
            return "Query Not generated"

from Agent_tools import df1, df2
from langchain_experimental.tools import PythonAstREPLTool
python_repl_tool = PythonAstREPLTool(locals={'df1':df1, 'df2':df2})
def execute_query(query):
    if query is None:
        return f"Query is empty"
    try:
        result = python_repl_tool.run(query)
    except Exception as e:
        return f"Error executing query: {e}"
    
    if isinstance(result, (pd.DataFrame, pd.Series)):
        return result.to_string()
    else:
        return str(result)

from langchain.output_parsers import PydanticOutputParser
supervisor_parser = PydanticOutputParser(pydantic_object=SupervisorResponse)
def validate_response(response):
    try:
        final_response = SupervisorResponse.model_validate(response)
        return_answer = final_response.final_response
        return return_answer.json() #converting to string
    except Exception as e:  
        return f"Error parsing final response: {e}"

# %%
#Create Supervisor Agent
from langchain_core.messages import HumanMessage
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from Agent_prompts import get_supervisor_prompt

members = ["Schema_Query_Agent"]
supervisor_prompt = get_supervisor_prompt()
options = ["FINISH", "EXECUTE_QUERY", "Schema_Query_Agent"]

final_supervisor_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", supervisor_prompt),
        MessagesPlaceholder(variable_name="messages"),
        (
            "system",
            "Given the conversation above, what should be the next action? "
            "Select one of: {options}",
        ),
    ]
).partial(options=str(options), members=", ".join(members), format_instructions=supervisor_parser.get_format_instructions())

def supervisor_agent(state):
    supervisor_chain = final_supervisor_prompt | llm.with_structured_output(SupervisorResponse)
    response = supervisor_chain.invoke(state)
    next_action = response.next_action

    if next_action=='EXECUTE_QUERY':
        query=extract_query_from_state(state)
        result=execute_query(query)
        answer_eq = f"The answer after executing query: {query} is {result}"
        state['messages'].append(HumanMessage(content=answer_eq, name="EXECUTE_QUERY"))
        state['next'] = "supervisor"
    elif next_action == "Schema_Query_Agent":
        state['next'] = "Schema_Query_Agent"
    elif next_action == "FINISH":
        final_response = validate_response(response)
        if final_response:
            state['messages'].append(HumanMessage(content=final_response, name="Supervisor"))
        else:
            state['messages'].append(HumanMessage(content="No final response provided.", name="Supervisor"))
        state['next'] = "FINISH"
    else:
        state['messages'].append(HumanMessage(content="Unexpected error", name="Supervisor"))
        state['next'] = "FINISH"
    return state

# %%
#Helper utility to create agent nodes in graph
from langchain_core.output_parsers import JsonOutputParser
schema_query_parser = JsonOutputParser(pydantic_object=SchemaQueryResponse)

def agent_node(state, agent, name):
    result = agent.invoke(state)
    agent_message = result["messages"][-1].content
    if schema_query_parser:
        try:
            output = schema_query_parser.parse(agent_message)
            answer = f"The constructed Pandas query is: {output.get("final_query")}"
        except Exception as e:
            output = f"Error parsing agent output: {e}"
            answer = f"The constructed Pandas query is: {output}"
    else:
        output = agent_message
        answer = f"The constructed Pandas query is: {output}"

    return {
        "messages": [HumanMessage(content=answer, name=name)]
    }

# %%
#Create Worker Agents
import functools
from langgraph.prebuilt import create_react_agent
from Agent_prompts import get_schema_query_prompt

#schema info and query builder agent
from langgraph.checkpoint.memory import MemorySaver
from langchain.tools.render import render_text_description
from Agent_tools import get_dataset_info_tool, get_dataset_indexing_structure, get_value_from_df

memory=MemorySaver()
schema_query_tools = [get_dataset_info_tool, get_dataset_indexing_structure, get_value_from_df]

# Create Tools description
tools_list = render_text_description(list(schema_query_tools))
tool_names = ", ".join((t.name for t in schema_query_tools))
format_instructions = schema_query_parser.get_format_instructions()
SQ_agent_prompt = get_schema_query_prompt(tools_list, tool_names, format_instructions)

schema_query_agent = create_react_agent(llm, tools=schema_query_tools, state_modifier=SQ_agent_prompt, checkpointer=memory)
schema_query_node = functools.partial(agent_node, agent=schema_query_agent, name="Schema_Query_Agent")

# %%
#Create langgraph flow
import operator
from typing import Sequence, Annotated
from typing_extensions import TypedDict
from langchain_core.messages import BaseMessage
from langgraph.graph import END, StateGraph, START

class AgentState(TypedDict):
    messages: Annotated[Sequence[BaseMessage], operator.add]
    next: str

workflow = StateGraph(AgentState)
workflow.add_node("Schema_Query_Agent", schema_query_node)
workflow.add_node("supervisor", supervisor_agent)

for member in members:
    workflow.add_edge(member, "supervisor")

conditional_map = {
    "Schema_Query_Agent": "Schema_Query_Agent",
    "EXECUTE_QUERY": "supervisor",  # Loop back to supervisor after execution
    "supervisor": "supervisor",
    "FINISH": END
}

workflow.add_conditional_edges("supervisor", lambda x: x["next"], conditional_map)
workflow.add_edge(START, "supervisor")
graph = workflow.compile()

# %%
# from IPython.display import Image, display
# display(Image(graph.get_graph(xray=True).draw_mermaid_png()))

# %%
# for s in graph.stream(
#     {
#         "messages": [
#             HumanMessage(content="What percentage of the population in the North West region of UK County is Male?")
#         ]
#     }
# ):
#     if "__end__" not in s:
#         print(s)
#         print("----")

# %%
final_state = graph.invoke(
    {
        "messages": [
            HumanMessage(content="What is the total percentage of females across all regions?")
        ]
    }
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 final_state = graph.invoke(
#       2     {
#       3         "messages": [
#       4             HumanMessage(content="What is the total percentage of females across all regions?")
#       5         ]
#       6     }
#       7 )
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:1560, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    1558 else:
#    1559     chunks = []
# -> 1560 for chunk in self.stream(
#    1561     input,
#    1562     config,
#    1563     stream_mode=stream_mode,
#    1564     output_keys=output_keys,
#    1565     interrupt_before=interrupt_before,
#    1566     interrupt_after=interrupt_after,
#    1567     debug=debug,
#    1568     **kwargs,
#    1569 ):
#    1570     if stream_mode == "values":
#    1571         latest = chunk
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:1298, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1287     # Similarly to Bulk Synchronous Parallel / Pregel model
#    1288     # computation proceeds in steps, while there are channel updates
#    1289     # channel updates from step N are only visible in step N+1
#    1290     # channels are guaranteed to be immutable for the duration of the step,
#    1291     # with channel updates applied only at the transition between steps
#    1292     while loop.tick(
#    1293         input_keys=self.input_channels,
#    1294         interrupt_before=interrupt_before_,
#    1295         interrupt_after=interrupt_after_,
#    1296         manager=run_manager,
#    1297     ):
# -> 1298         for _ in runner.tick(
#    1299             loop.tasks.values(),
#    1300             timeout=self.step_timeout,
#    1301             retry_policy=self.retry_policy,
#    1302             get_waiter=get_waiter,
#    1303         ):
#    1304             # emit output
#    1305             yield from output()
#    1306 # emit output
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langgraph/pregel/runner.py:56, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#      54 t = tasks[0]
#      55 try:
# ---> 56     run_with_retry(t, retry_policy)
#      57     self.commit(t, None)
#      58 except Exception as exc:
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langgraph/pregel/retry.py:29, in run_with_retry(task, retry_policy)
#      27 task.writes.clear()
#      28 # run the task
# ---> 29 task.proc.invoke(task.input, config)
#      30 # if successful, end
#      31 break
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langgraph/utils/runnable.py:409, in RunnableSeq.invoke(self, input, config, **kwargs)
#     407 context.run(_set_config_context, config)
#     408 if i == 0:
# --> 409     input = context.run(step.invoke, input, config, **kwargs)
#     410 else:
#     411     input = context.run(step.invoke, input, config)
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langgraph/utils/runnable.py:183, in RunnableCallable.invoke(self, input, config, **kwargs)
#     181 else:
#     182     context.run(_set_config_context, config)
# --> 183     ret = context.run(self.func, input, **kwargs)
#     184 if isinstance(ret, Runnable) and self.recurse:
#     185     return ret.invoke(input, config)
#
# Cell In[5], line 3, in agent_node(state, agent, name)
#       2 def agent_node(state, agent, name):
# ----> 3     result = agent.invoke(state)
#       4     agent_message = result["messages"][-1].content
#       5     if schema_query_parser:
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:1560, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    1558 else:
#    1559     chunks = []
# -> 1560 for chunk in self.stream(
#    1561     input,
#    1562     config,
#    1563     stream_mode=stream_mode,
#    1564     output_keys=output_keys,
#    1565     interrupt_before=interrupt_before,
#    1566     interrupt_after=interrupt_after,
#    1567     debug=debug,
#    1568     **kwargs,
#    1569 ):
#    1570     if stream_mode == "values":
#    1571         latest = chunk
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:1298, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1287     # Similarly to Bulk Synchronous Parallel / Pregel model
#    1288     # computation proceeds in steps, while there are channel updates
#    1289     # channel updates from step N are only visible in step N+1
#    1290     # channels are guaranteed to be immutable for the duration of the step,
#    1291     # with channel updates applied only at the transition between steps
#    1292     while loop.tick(
#    1293         input_keys=self.input_channels,
#    1294         interrupt_before=interrupt_before_,
#    1295         interrupt_after=interrupt_after_,
#    1296         manager=run_manager,
#    1297     ):
# -> 1298         for _ in runner.tick(
#    1299             loop.tasks.values(),
#    1300             timeout=self.step_timeout,
#    1301             retry_policy=self.retry_policy,
#    1302             get_waiter=get_waiter,
#    1303         ):
#    1304             # emit output
#    1305             yield from output()
#    1306 # emit output
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langgraph/pregel/runner.py:56, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#      54 t = tasks[0]
#      55 try:
# ---> 56     run_with_retry(t, retry_policy)
#      57     self.commit(t, None)
#      58 except Exception as exc:
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langgraph/pregel/retry.py:29, in run_with_retry(task, retry_policy)
#      27 task.writes.clear()
#      28 # run the task
# ---> 29 task.proc.invoke(task.input, config)
#      30 # if successful, end
#      31 break
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langgraph/utils/runnable.py:409, in RunnableSeq.invoke(self, input, config, **kwargs)
#     407 context.run(_set_config_context, config)
#     408 if i == 0:
# --> 409     input = context.run(step.invoke, input, config, **kwargs)
#     410 else:
#     411     input = context.run(step.invoke, input, config)
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:4700, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4686 """Invoke this Runnable synchronously.
#    4687
#    4688 Args:
#    (...)
#    4697     TypeError: If the Runnable is a coroutine function.
#    4698 """
#    4699 if hasattr(self, "func"):
# -> 4700     return self._call_with_config(
#    4701         self._invoke,
#    4702         input,
#    4703         self._config(config, self.func),
#    4704         **kwargs,
#    4705     )
#    4706 else:
#    4707     raise TypeError(
#    4708         "Cannot invoke a coroutine function synchronously."
#    4709         "Use `ainvoke` instead."
#    4710     )
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:1926, in Runnable._call_with_config(self, func, input, config, run_type, serialized, **kwargs)
#    1922     context = copy_context()
#    1923     context.run(_set_config_context, child_config)
#    1924     output = cast(
#    1925         Output,
# -> 1926         context.run(
#    1927             call_func_with_variable_args,  # type: ignore[arg-type]
#    1928             func,  # type: ignore[arg-type]
#    1929             input,  # type: ignore[arg-type]
#    1930             config,
#    1931             run_manager,
#    1932             **kwargs,
#    1933         ),
#    1934     )
#    1935 except BaseException as e:
#    1936     run_manager.on_chain_error(e)
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langchain_core/runnables/config.py:394, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     392 if run_manager is not None and accepts_run_manager(func):
#     393     kwargs["run_manager"] = run_manager
# --> 394 return func(input, **kwargs)
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:4556, in RunnableLambda._invoke(self, input, run_manager, config, **kwargs)
#    4554                 output = chunk
#    4555 else:
# -> 4556     output = call_func_with_variable_args(
#    4557         self.func, input, config, run_manager, **kwargs
#    4558     )
#    4559 # If the output is a Runnable, invoke it
#    4560 if isinstance(output, Runnable):
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langchain_core/runnables/config.py:394, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     392 if run_manager is not None and accepts_run_manager(func):
#     393     kwargs["run_manager"] = run_manager
# --> 394 return func(input, **kwargs)
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langgraph/prebuilt/chat_agent_executor.py:481, in create_react_agent.<locals>.call_model(state, config)
#     480 def call_model(state: AgentState, config: RunnableConfig) -> AgentState:
# --> 481     response = model_runnable.invoke(state, config)
#     482     if (
#     483         state["is_last_step"]
#     484         and isinstance(response, AIMessage)
#     485         and response.tool_calls
#     486     ):
#     487         return {
#     488             "messages": [
#     489                 AIMessage(
#    (...)
#     493             ]
#     494         }
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3022, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3020             input = context.run(step.invoke, input, config, **kwargs)
#    3021         else:
# -> 3022             input = context.run(step.invoke, input, config)
#    3023 # finish the root run
#    3024 except BaseException as e:
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:5337, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5331 def invoke(
#    5332     self,
#    5333     input: Input,
#    5334     config: Optional[RunnableConfig] = None,
#    5335     **kwargs: Optional[Any],
#    5336 ) -> Output:
# -> 5337     return self.bound.invoke(
#    5338         input,
#    5339         self._merge_configs(config),
#    5340         **{**self.kwargs, **kwargs},
#    5341     )
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:284, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     273 def invoke(
#     274     self,
#     275     input: LanguageModelInput,
#    (...)
#     279     **kwargs: Any,
#     280 ) -> BaseMessage:
#     281     config = ensure_config(config)
#     282     return cast(
#     283         ChatGeneration,
# --> 284         self.generate_prompt(
#     285             [self._convert_input(input)],
#     286             stop=stop,
#     287             callbacks=config.get("callbacks"),
#     288             tags=config.get("tags"),
#     289             metadata=config.get("metadata"),
#     290             run_name=config.get("run_name"),
#     291             run_id=config.pop("run_id", None),
#     292             **kwargs,
#     293         ).generations[0][0],
#     294     ).message
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:784, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     776 def generate_prompt(
#     777     self,
#     778     prompts: list[PromptValue],
#    (...)
#     781     **kwargs: Any,
#     782 ) -> LLMResult:
#     783     prompt_messages = [p.to_messages() for p in prompts]
# --> 784     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:641, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     639         if run_managers:
#     640             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 641         raise e
#     642 flattened_outputs = [
#     643     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     644     for res in results
#     645 ]
#     646 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:631, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     628 for i, m in enumerate(messages):
#     629     try:
#     630         results.append(
# --> 631             self._generate_with_cache(
#     632                 m,
#     633                 stop=stop,
#     634                 run_manager=run_managers[i] if run_managers else None,
#     635                 **kwargs,
#     636             )
#     637         )
#     638     except BaseException as e:
#     639         if run_managers:
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:850, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     848 else:
#     849     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 850         result = self._generate(
#     851             messages, stop=stop, run_manager=run_manager, **kwargs
#     852         )
#     853     else:
#     854         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:683, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     681     generation_info = {"headers": dict(raw_response.headers)}
#     682 else:
# --> 683     response = self.client.create(**payload)
#     684 return self._create_chat_result(response, generation_info)
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/openai/resources/chat/completions.py:742, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     704 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     705 def create(
#     706     self,
#    (...)
#     739     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     740 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     741     validate_response_format(response_format)
# --> 742     return self._post(
#     743         "/chat/completions",
#     744         body=maybe_transform(
#     745             {
#     746                 "messages": messages,
#     747                 "model": model,
#     748                 "frequency_penalty": frequency_penalty,
#     749                 "function_call": function_call,
#     750                 "functions": functions,
#     751                 "logit_bias": logit_bias,
#     752                 "logprobs": logprobs,
#     753                 "max_completion_tokens": max_completion_tokens,
#     754                 "max_tokens": max_tokens,
#     755                 "metadata": metadata,
#     756                 "n": n,
#     757                 "parallel_tool_calls": parallel_tool_calls,
#     758                 "presence_penalty": presence_penalty,
#     759                 "response_format": response_format,
#     760                 "seed": seed,
#     761                 "service_tier": service_tier,
#     762                 "stop": stop,
#     763                 "store": store,
#     764                 "stream": stream,
#     765                 "stream_options": stream_options,
#     766                 "temperature": temperature,
#     767                 "tool_choice": tool_choice,
#     768                 "tools": tools,
#     769                 "top_logprobs": top_logprobs,
#     770                 "top_p": top_p,
#     771                 "user": user,
#     772             },
#     773             completion_create_params.CompletionCreateParams,
#     774         ),
#     775         options=make_request_options(
#     776             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     777         ),
#     778         cast_to=ChatCompletion,
#     779         stream=stream or False,
#     780         stream_cls=Stream[ChatCompletionChunk],
#     781     )
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/openai/_base_client.py:1271, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1257 def post(
#    1258     self,
#    1259     path: str,
#    (...)
#    1266     stream_cls: type[_StreamT] | None = None,
#    1267 ) -> ResponseT | _StreamT:
#    1268     opts = FinalRequestOptions.construct(
#    1269         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1270     )
# -> 1271     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/openai/_base_client.py:948, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     945 else:
#     946     retries_taken = 0
# --> 948 return self._request(
#     949     cast_to=cast_to,
#     950     options=options,
#     951     stream=stream,
#     952     stream_cls=stream_cls,
#     953     retries_taken=retries_taken,
#     954 )
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/openai/_base_client.py:1037, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1035 if remaining_retries > 0 and self._should_retry(err.response):
#    1036     err.response.close()
# -> 1037     return self._retry_request(
#    1038         input_options,
#    1039         cast_to,
#    1040         retries_taken=retries_taken,
#    1041         response_headers=err.response.headers,
#    1042         stream=stream,
#    1043         stream_cls=stream_cls,
#    1044     )
#    1046 # If the response is streamed then we need to explicitly read the response
#    1047 # to completion before attempting to access the response text.
#    1048 if not err.response.is_closed:
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/openai/_base_client.py:1086, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1082 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1083 # different thread if necessary.
#    1084 time.sleep(timeout)
# -> 1086 return self._request(
#    1087     options=options,
#    1088     cast_to=cast_to,
#    1089     retries_taken=retries_taken + 1,
#    1090     stream=stream,
#    1091     stream_cls=stream_cls,
#    1092 )
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/openai/_base_client.py:1037, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1035 if remaining_retries > 0 and self._should_retry(err.response):
#    1036     err.response.close()
# -> 1037     return self._retry_request(
#    1038         input_options,
#    1039         cast_to,
#    1040         retries_taken=retries_taken,
#    1041         response_headers=err.response.headers,
#    1042         stream=stream,
#    1043         stream_cls=stream_cls,
#    1044     )
#    1046 # If the response is streamed then we need to explicitly read the response
#    1047 # to completion before attempting to access the response text.
#    1048 if not err.response.is_closed:
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/openai/_base_client.py:1086, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1082 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1083 # different thread if necessary.
#    1084 time.sleep(timeout)
# -> 1086 return self._request(
#    1087     options=options,
#    1088     cast_to=cast_to,
#    1089     retries_taken=retries_taken + 1,
#    1090     stream=stream,
#    1091     stream_cls=stream_cls,
#    1092 )
#
# File ~/AI-Powered-Dataset-Analyzer/testing/.venv/lib/python3.12/site-packages/openai/_base_client.py:1052, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1049         err.response.read()
#    1051     log.debug("Re-raising status error")
# -> 1052     raise self._make_status_error_from_response(err.response) from None
#    1054 return self._process_response(
#    1055     cast_to=cast_to,
#    1056     options=options,
#    (...)
#    1060     retries_taken=retries_taken,
#    1061 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-UtoxPjBKNg59Qae4d40fRbXl on requests per min (RPM): Limit 3, Used 3, Requested 1. Please try again in 20s. Visit https://platform.openai.com/account/rate-limits to learn more. You can increase your rate limit by adding a payment method to your account at https://platform.openai.com/account/billing.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}

# %%
print(final_state["messages"][-1].content)
# Out:
# {"original_user_query":"How many females are there in the West Midlands region?","constructed_pandas_query":"df.loc[('Gender', 'Female', 'Value'), ('UK County', 'West Midlands')]","output":"50.0","charts":null}
